# %% [markdown]
# # Computing Optimal Labels
# Backtesting a Always Buy/Sell Strategies to compute Optimal strategy for a day-ticker combination using MILP

# %%
# !pip install import_ipynb --quiet
# !pip install anvil-uplink --quiet
# !pip install yfinance --quiet
# !pip install pandas_ta --quiet
# !pip install ipynb --quiet
# !pip install rpyc --quiet
# !pip install pulp

# %%
# # pull files from Github
# !git clone https://github.com/gmshroff/algostrats.git

# %%
# %cd algostrats

# %%
# change to True if on colab
colab=False

# %%
import pandas as pd
import numpy as np
import import_ipynb
from backtest import Backtest
from feeds import BackFeed,DataFeed
from validation import Validate
import pickle
from itertools import product
from tqdm.notebook import tqdm
# Out:
# importing Jupyter notebook from backtest.ipynb
# importing Jupyter notebook from feeds.ipynb
# importing Jupyter notebook from synfeed.ipynb
# importing Jupyter notebook from india_calendar.ipynb
# importing Jupyter notebook from featfuncs.ipynb
# importing Jupyter notebook from feed_env.ipynb
# importing Jupyter notebook from validation.ipynb

# %%
from rulestrats import RuleStrat,do_nothing,always_buy,always_sell
# Out:
# importing Jupyter notebook from rulestrats.ipynb

# %%
from pulp_jobs import Jobs
from featfuncs import feat_aug,add_addl_features_feed,add_ta_features_feed,add_sym_feature_feed
from featfuncs import add_global_indices_feed
# Out:
# importing Jupyter notebook from pulp_jobs.ipynb

# %%
import warnings
warnings.simplefilter("ignore")

# %%
loadfeed=True
savefeed=False
synthetic=False

# %% [markdown]
# Deterministic Strategy - 1 or -1

# %%
class DetStrat(RuleStrat):
    def __init__(self,action=0):
        self.action=action
        self.data_cols=['row_num','Close']
        self.model_type='rule-based'
        super().__init__()
    def check_entry_batch(self,dfD):
        if self.action==-1: return always_sell(dfD)
        elif self.action==1: return always_buy(dfD)
        else: return do_nothing(dfD)

# %%
data=pd.read_csv('./capvol100.csv')

# %%
tickers=list(data.iloc[0:50]['ticker'].values)

# %%
def stringify(x):
    return pd.to_datetime(x['Datetime']).strftime('%d-%b-%Y')

# %%
loadfeed_path = '../algodata/realdata/datafeed_augdata_03-Feb-2022_5m_True_False.pkl'

# %%
if not loadfeed:
    feed=BackFeed(tickers=tickers,nd=3,nw=1,synthetic=synthetic)
    if savefeed: 
        with open('../../temp_data/feed.pickle','wb') as f: pickle.dump(feed,f)
elif loadfeed:
    with open(loadfeed_path,'rb') as f: feed=pickle.load(f)

# %% [markdown]
# Gather Data for Computing Optimal Strategies for a given Feed

# %%
def assemble_backtests(feed,topk=3,actions=[-1,1],
                       stops=[.01,.005,.02],
                       targets=[.01,.005,.02]):
    posD={}
    print('Assembling backtests')
    for idx, (action,stop,target) in tqdm(enumerate([c for c in product(actions,stops,targets)])):
        detStrat=DetStrat(action)
        try:
            with open(loadfeed_path,'rb') as f: feed=pickle.load(f)
            bt=Backtest(feed,tickers=feed.tickers,add_features=True,target=target,stop=stop,txcost=0.001,
                        loc_exit=True,scan=True,topk=3,deploy=False,save_dfs=False)
        except:
            print(f'Error on idx: {idx, action, stop, target}, datesQ: {feed.datesQ}')
            continue
        bt.run_all(tickers=feed.tickers,model=detStrat,verbose=False)
        for t in bt.results:
            if t not in posD: posD[t]={}
            for d in bt.results[t]:
                if d not in posD[t]: posD[t][d]=[]
                max_r=0
                max_e=0
                for p in bt.results[t][d]['rew']:
                    if p[1]>0 and (p[1]>max_r or p[0]>=max_e): 
                        posD[t][d]+=[(p[0],p[2],p[1],(p[0],action,stop,target,p[2],p[1]))]
                        max_r,max_e=max(max_r,p[1]),max(max_e,p[2])
    return posD

# %%
def compute_optimal(posD,min_row=0):
    optD={}
    for t in posD:
        if t not in optD: optD[t]={}
        for d in posD[t]:
            print(f'Computing optimal strategy for {t} on {d} starting from {min_row}')
            jobs=Jobs()
            for p in posD[t][d]:
                if p[0]>=min_row: jobs.add_job(p[0],p[1],p[2],p[3])
            if jobs.k>0:
                jobs.setup()
                jobs.solve()
                x=jobs.get_soln()
                optD[t][d]=[j for i,j in enumerate(jobs.dL) if x[i]>0]
            else: optD[t][d]=[]
    [optD[t][d].sort(key=lambda x: x[0]) for t in optD for d in optD[t]]
    optR={t+' '+d:(lambda x: sum(x) if len(x)>0 else 0)([o[5] for o in optD[t][d]]) for t in optD for d in optD[t]}
    return optD,optR

# %%
loadposD=False

# %%
if loadposD: 
    with open('../../temp_data/posD.pickle','rb') as f: posD=pickle.load(f)
else: 
    posD=assemble_backtests(feed)
    if loadfeed:
        posD_path = loadfeed_path.rstrip('.pkl') + "_optimal_posD.pkl"
    else:
        posD_path = 'posD.pkl'
    with open(posD_path,'wb') as f: pickle.dump(posD,f)
# Out:
# Assembling backtests
# 0it [00:00, ?it/s]

# %%
optD,optR=compute_optimal(posD,min_row=5)
# Out:
# Computing optimal strategy for MUTHOOTFIN.NS on 17-Jan-2022 starting from 5
# Computing optimal strategy for WONDERLA.NS on 01-Feb-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 01-Feb-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 24-Jan-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 02-Feb-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 14-Jan-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 13-Jan-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 19-Jan-2022 starting from 5
# Computing optimal strategy for VIPIND.NS on 12-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 25-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 11-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 10-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 20-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 13-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 19-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 07-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 18-Jan-2022 starting from 5
# Computing optimal strategy for MTNL.NS on 31-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 21-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 11-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 24-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 02-Feb-2022 starting from 5
# Computing optimal strategy for TRF.NS on 19-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 12-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 07-Jan-2022 starting from 5
# Computing optimal strategy for TRF.NS on 31-Jan-2022 starting from 5
# Computing optimal strategy for TATAMTRDVR.NS on 25-Jan-2022 starting from 5
# Computing optimal strategy for TATAMTRDVR.NS on 20-Jan-2022 starting from 5
# Computing optimal strategy for TATAMTRDVR.NS on 18-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 25-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 21-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 10-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 24-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 17-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 20-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 02-Feb-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 13-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 07-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 18-Jan-2022 starting from 5
# Computing optimal strategy for VARDHACRLC.NS on 31-Jan-2022 starting from 5
# Computing optimal strategy for KOTAKBANK.NS on 21-Jan-2022 starting from 5
# Computing optimal strategy for KOTAKBANK.NS on 01-Feb-2022 starting from 5
# Computing optimal strategy for KOTAKBANK.NS on 14-Jan-2022 starting from 5
# Computing optimal strategy for SCHNEIDER.NS on 11-Jan-2022 starting from 5
# Computing optimal strategy for SCHNEIDER.NS on 10-Jan-2022 starting from 5
# Computing optimal strategy for SCHNEIDER.NS on 17-Jan-2022 starting from 5
# Computing optimal strategy for SCHNEIDER.NS on 14-Jan-2022 starting from 5
# Computing optimal strategy for SCHNEIDER.NS on 12-Jan-2022 starting from 5

# %%
optD,optR
# Out:
# ({'MUTHOOTFIN.NS': {'17-Jan-2022': [(16,
#      1,
#      0.005,
#      0.02,
#      74,
#      1.0868756122982919)]},
#   'WONDERLA.NS': {'01-Feb-2022': [(15, -1, 0.01, 0.01, 27, 1.078176055899261),
#     (28, -1, 0.01, 0.005, 39, 0.4246781779419758),
#     (47, 1, 0.005, 0.005, 57, 0.6258883376768647),
#     (58, -1, 0.005, 0.005, 62, 0.8100000000000145)]},
#   'VIPIND.NS': {'01-Feb-2022': [(16, -1, 0.005, 0.01, 29, 1.075095816202822),
#     (31, 1, 0.02, 0.01, 41, 1.6398093213615588),
#     (44, -1, 0.005, 0.005, 48, 0.9916646765370359),
#     (54, 1, 0.01, 0.02, 74, 1.2555731656427775)],
#    '24-Jan-2022': [(6, -1, 0.005, 0.02, 13, 3.490952762560374),
#     (13, -1, 0.01, 0.005, 15, 0.41922587939444433),
#     (15, 1, 0.02, 0.02, 22, 2.50847457627119),
#     (28, -1, 0.01, 0.02, 66, 1.9410404181976262),
#     (71, -1, 0.005, 0.02, 74, 0.06931579772124495)],
#    '02-Feb-2022': [(5, -1, 0.01, 0.02, 18, 2.4586149393807095),
#     (26, 1, 0.005, 0.005, 30, 0.670063868825095),
#     (30, 1, 0.01, 0.005, 35, 0.47634224524864877),
#     (35, 1, 0.005, 0.005, 41, 0.49653662420382433),
#     (41, 1, 0.01, 0.005, 47, 0.6431643376927143),
#     (47, -1, 0.01, 0.005, 57, 0.4877632281379683),
#     (61, 1, 0.005, 0.02, 69, 4.857469129615519),
#     (71, -1, 0.01, 0.02, 74, 1.9878585692527062)],
#    '14-Jan-2022': [(5, -1, 0.005, 0.005, 8, 0.5774957698815681),
#     (10, 1, 0.005, 0.005, 19, 0.5057109829505977),
#     (27, 1, 0.005, 0.005, 35, 0.4129653401797096),
#     (42, 1, 0.005, 0.005, 48, 0.47321002387882416),
#     (48, 1, 0.005, 0.005, 51, 0.5710990127252258),
#     (52, -1, 0.02, 0.02, 72, 0.8807073953989333)],
#    '13-Jan-2022': [(11, 1, 0.01, 0.005, 13, 0.4386995264930056),
#     (15, 1, 0.01, 0.005, 32, 0.4791345932904392),
#     (48, 1, 0.02, 0.005, 50, 0.5498096073011554),
#     (65, -1, 0.005, 0.005, 71, 0.46260729619309965)],
#    '19-Jan-2022': [(5, 1, 0.005, 0.005, 7, 0.67039464324868),
#     (7, 1, 0.005, 0.005, 12, 0.817532293622587),
#     (14, -1, 0.005, 0.005, 29, 0.5603078037362941),
#     (34, 1, 0.005, 0.01, 38, 1.0752920078158748),
#     (38, 1, 0.005, 0.005, 48, 0.4050230925323645),
#     (51, -1, 0.02, 0.01, 54, 1.8545026666881363),
#     (55, 1, 0.005, 0.02, 72, 2.5552049260718177),
#     (72, 1, 0.01, 0.005, 74, 0.010325249164682615)],
#    '12-Jan-2022': [(5, -1, 0.02, 0.005, 9, 0.7227376336920637),
#     (12, 1, 0.005, 0.005, 21, 0.49572418417500036),
#     (29, -1, 0.005, 0.005, 34, 0.5068768532966622),
#     (34, 1, 0.005, 0.01, 50, 1.1094873865458958),
#     (51, -1, 0.01, 0.01, 54, 0.9215182821259503),
#     (60, 1, 0.01, 0.005, 64, 2.556779735004782),
#     (65, -1, 0.01, 0.005, 67, 0.5720939991607281),
#     (67, -1, 0.01, 0.005, 72, 0.4061093997744881)]},
#   'MTNL.NS': {'25-Jan-2022': [(5, 1, 0.02, 0.01, 9, 1.1577352182878358),
#     (10, -1, 0.005, 0.005, 12, 0.793750000000005),
#     (12, -1, 0.01, 0.005, 19, 0.4420632608995345),
#     (21, -1, 0.005, 0.005, 33, 0.4440203480925008),
#     (35, -1, 0.01, 0.005, 38, 0.4450077034732336),
#     (65, -1, 0.005, 0.02, 74, 1.335124099008511)],
#    '11-Jan-2022': [(5, 1, 0.01, 0.01, 7, 1.2560993381644407),
#     (7, 1, 0.01, 0.005, 16, 0.6455223880597044),
#     (17, -1, 0.005, 0.005, 38, 0.49850750115439674),
#     (38, 1, 0.005, 0.01, 43, 2.608125580750294),
#     (43, -1, 0.01, 0.01, 55, 1.2366491201916006),
#     (55, -1, 0.02, 0.005, 66, 1.2506655646175335),
#     (67, -1, 0.02, 0.02, 74, 0.052136937653940285)],
#    '10-Jan-2022': [(5, -1, 0.005, 0.005, 7, 0.46078644096339205),
#     (15, -1, 0.01, 0.02, 19, 3.1290364043018317),
#     (19, -1, 0.005, 0.005, 33, 0.4769474331430443),
#     (39, -1, 0.005, 0.005, 64, 0.6201438848920945),
#     (64, -1, 0.005, 0.005, 71, 0.4802920687025855)],
#    '20-Jan-2022': [(9, 1, 0.02, 0.005, 13, 1.0333885794642614),
#     (13, -1, 0.005, 0.005, 18, 0.5406424438476465),
#     (34, -1, 0.005, 0.01, 61, 1.0175450640768704),
#     (62, 1, 0.005, 0.01, 73, 2.1594469773732548)],
#    '13-Jan-2022': [(5, -1, 0.005, 0.005, 7, 0.8326122311748865),
#     (7, -1, 0.005, 0.005, 10, 0.8399096662993489),
#     (12, -1, 0.02, 0.005, 16, 1.4788643153130034),
#     (16, -1, 0.02, 0.005, 18, 0.5406424438476528),
#     (21, 1, 0.02, 0.01, 26, 2.790995523741058),
#     (26, 1, 0.01, 0.01, 32, 1.150697038899528),
#     (36, -1, 0.005, 0.005, 42, 0.9931309857570743),
#     (42, -1, 0.005, 0.005, 46, 0.5275826233243098),
#     (67, -1, 0.005, 0.005, 72, 0.3692175567150146)],
#    '19-Jan-2022': [(5, 1, 0.02, 0.01, 10, 1.1952985866145016),
#     (10, -1, 0.005, 0.02, 45, 2.1458357261795684),
#     (49, -1, 0.005, 0.005, 51, 0.5510593941541194),
#     (55, -1, 0.005, 0.005, 74, 0.5499962967710691)],
#    '07-Jan-2022': [(22, 1, 0.005, 0.01, 29, 0.9179106319115741),
#     (29, -1, 0.005, 0.005, 32, 1.1888433587104377),
#     (33, -1, 0.005, 0.01, 39, 2.640492054161667),
#     (39, -1, 0.02, 0.01, 41, 2.1511245407779085),
#     (41, 1, 0.02, 0.02, 47, 2.9226929593383226),
#     (47, -1, 0.005, 0.01, 55, 1.217107466823567),
#     (60, 1, 0.01, 0.01, 68, 1.9567669475779825),
#     (69, 1, 0.005, 0.01, 74, 1.3436416821625001)],
#    '18-Jan-2022': [(10, -1, 0.005, 0.005, 13, 0.5188468458524937),
#     (16, -1, 0.005, 0.005, 56, 0.6735703610625815),
#     (56, -1, 0.005, 0.005, 62, 0.8340626167991473),
#     (62, -1, 0.005, 0.01, 69, 1.0000011857300655),
#     (73, -1, 0.01, 0.01, 74, 0.058389699206897856)],
#    '31-Jan-2022': [(6, -1, 0.005, 0.01, 10, 1.1648027877311018),
#     (11, 1, 0.005, 0.01, 15, 1.0018354022689295),
#     (20, 1, 0.005, 0.005, 24, 1.173764903201888),
#     (25, 1, 0.01, 0.005, 29, 0.4459002358719601),
#     (29, 1, 0.01, 0.005, 33, 0.8081818181818231),
#     (34, 1, 0.02, 0.005, 36, 0.44490770513363864),
#     (37, -1, 0.005, 0.005, 60, 0.4459986114501886),
#     (63, -1, 0.005, 0.01, 66, 0.9841196291783518),
#     (68, -1, 0.01, 0.005, 71, 0.44899311171686457)]},
#   'TRF.NS': {'21-Jan-2022': [(6, -1, 0.02, 0.005, 7, 4.526903819518674)],
#    '11-Jan-2022': [],
#    '24-Jan-2022': [],
#    '02-Feb-2022': [(5, -1, 0.02, 0.01, 7, 0.6641221374045789)],
#    '19-Jan-2022': [],
#    '12-Jan-2022': [],
#    '07-Jan-2022': [(5, 1, 0.005, 0.02, 7, 1.8500046223134565)],
#    '31-Jan-2022': []},
#   'TATAMTRDVR.NS': {'25-Jan-2022': [(6,
#      1,
#      0.005,
#      0.005,
#      8,
#      0.4020087671582414),
#     (8, -1, 0.005, 0.005, 12, 0.7747840544830829),
#     (15, -1, 0.005, 0.005, 19, 0.4222245275984828),
#     (26, -1, 0.01, 0.005, 42, 0.48040749972809577),
#     (50, 1, 0.005, 0.005, 57, 0.7278433600465974),
#     (61, -1, 0.02, 0.005, 74, 0.04456616496617402)],
#    '20-Jan-2022': [(6, -1, 0.005, 0.01, 18, 1.0615249221851157),
#     (31, 1, 0.005, 0.005, 37, 0.5535623120544171),
#     (39, -1, 0.01, 0.01, 57, 1.1808730778762557),
#     (73, -1, 0.005, 0.005, 74, 0.07196495447469221)],
#    '18-Jan-2022': [(5, 1, 0.005, 0.01, 12, 0.9664195281793743),
#     (38, -1, 0.005, 0.02, 72, 2.133696681813504),
#     (73, -1, 0.01, 0.005, 74, 0.13091353153605975)]},
#   'VARDHACRLC.NS': {'25-Jan-2022': [(7,
#      -1,
#      0.01,
#      0.005,
#      10,
#      1.467931969954892),
#     (12, -1, 0.005, 0.005, 14, 0.565118807857693),
#     (14, 1, 0.005, 0.005, 16, 0.5715992005933229),
#     (16, 1, 0.005, 0.005, 20, 0.40116930041319987),
#     (20, 1, 0.005, 0.005, 23, 1.1394540786496525),
#     (23, 1, 0.01, 0.005, 25, 1.1374071171604725),
#     (26, -1, 0.005, 0.01, 37, 1.0393508352884455),
#     (44, -1, 0.01, 0.005, 46, 0.5521197352674715),
#     (49, -1, 0.01, 0.02, 55, 0.7092158647496353)],
#    '21-Jan-2022': [(6, -1, 0.005, 0.02, 19, 1.9124325270110536),
#     (20, -1, 0.005, 0.005, 23, 1.1087593280144328),
#     (23, -1, 0.005, 0.005, 32, 0.7411695087182696),
#     (32, -1, 0.005, 0.005, 44, 0.5160023498535201),
#     (44, -1, 0.005, 0.005, 46, 1.672359912210856)],
#    '10-Jan-2022': [(5, 1, 0.02, 0.01, 12, 1.2342223997743973),
#     (12, 1, 0.005, 0.005, 14, 0.5604983873603789),
#     (14, -1, 0.02, 0.02, 58, 2.2951270325695763),
#     (58, -1, 0.005, 0.005, 61, 0.4055606853456766),
#     (61, -1, 0.02, 0.005, 64, 0.3220067507919986)],
#    '24-Jan-2022': [(6, -1, 0.005, 0.005, 10, 0.5612679008057719),
#     (10, -1, 0.005, 0.005, 13, 0.7313953383005939),
#     (14, -1, 0.005, 0.005, 16, 0.5684499452504967),
#     (28, 1, 0.02, 0.01, 40, 0.992258545226543),
#     (45, -1, 0.005, 0.005, 51, 0.5723723157390678),
#     (53, 1, 0.005, 0.005, 58, 0.7437499891261807)],
#    '17-Jan-2022': [(5, 1, 0.01, 0.005, 9, 1.1155179448000732),
#     (9, 1, 0.01, 0.005, 11, 1.1109137101607007),
#     (11, 1, 0.01, 0.005, 15, 0.4981944376234091),
#     (15, 1, 0.01, 0.005, 20, 0.8757233250355766),
#     (20, 1, 0.02, 0.005, 22, 0.41684917629044793),
#     (23, -1, 0.02, 0.01, 26, 1.733333333333338),
#     (27, -1, 0.01, 0.01, 31, 1.217107466823581),
#     (31, -1, 0.01, 0.005, 36, 0.4178839093760934),
#     (36, -1, 0.01, 0.005, 45, 0.4936158761995325),
#     (48, 1, 0.01, 0.02, 54, 3.713540884073168),
#     (54, 1, 0.01, 0.005, 57, 0.47454189080410597),
#     (57, 1, 0.01, 0.005, 59, 0.47372794773672694),
#     (59, -1, 0.02, 0.005, 64, 0.539385329599598),
#     (65, -1, 0.01, 0.005, 72, 0.042590423001041065)],
#    '20-Jan-2022': [(8, -1, 0.01, 0.005, 10, 1.1708715629262645),
#     (10, 1, 0.005, 0.005, 12, 1.0482758620689612),
#     (12, -1, 0.005, 0.005, 14, 0.503468781632233),
#     (14, -1, 0.005, 0.005, 17, 0.956869607784694),
#     (17, -1, 0.01, 0.005, 19, 0.7322797310808579),
#     (20, -1, 0.005, 0.005, 23, 0.4300279586729175),
#     (23, -1, 0.005, 0.005, 29, 0.5830128370497737),
#     (29, -1, 0.005, 0.005, 34, 0.969766328535015),
#     (35, -1, 0.005, 0.005, 49, 0.5160023498535135),
#     (49, -1, 0.005, 0.005, 53, 0.8225783205417024),
#     (56, 1, 0.01, 0.01, 61, 1.5351448199385689),
#     (62, 1, 0.01, 0.01, 66, 1.353364329158932),
#     (66, 1, 0.01, 0.01, 67, 0.35409552834250546)],
#    '02-Feb-2022': [(9, 1, 0.005, 0.01, 21, 0.9456546542809326),
#     (25, 1, 0.01, 0.005, 30, 0.4585499920964068),
#     (30, -1, 0.01, 0.005, 34, 1.1751580350737114),
#     (36, 1, 0.005, 0.005, 38, 0.5403809354150886),
#     (46, 1, 0.01, 0.005, 47, 0.13899156562534237)],
#    '13-Jan-2022': [(13, 1, 0.005, 0.005, 15, 0.5687891620971265),
#     (22, -1, 0.005, 0.005, 25, 0.48198054263625373),
#     (26, 1, 0.01, 0.005, 33, 1.229788800327842),
#     (33, -1, 0.01, 0.005, 43, 1.048689776561301),
#     (43, -1, 0.005, 0.005, 55, 0.5612679008057644)],
#    '07-Jan-2022': [(8, -1, 0.005, 0.01, 11, 1.3075306540423006),
#     (13, -1, 0.005, 0.005, 16, 0.4839141209920264),
#     (16, -1, 0.005, 0.005, 20, 0.5673358790079863),
#     (20, -1, 0.005, 0.005, 24, 0.8252928341136114),
#     (24, -1, 0.02, 0.005, 28, 0.40556068534568124),
#     (28, -1, 0.02, 0.005, 30, 0.49181129491895836),
#     (30, -1, 0.005, 0.005, 34, 0.6641234230239175),
#     (36, 1, 0.005, 0.005, 38, 0.9263672260031768),
#     (38, 1, 0.005, 0.005, 43, 0.5824962076175352),
#     (43, 1, 0.005, 0.005, 52, 0.576144728714355),
#     (55, -1, 0.005, 0.005, 58, 0.9111149422201771),
#     (59, 1, 0.005, 0.005, 62, 1.1709923499628372),
#     (63, -1, 0.005, 0.005, 65, 0.49280622951050446)],
#    '18-Jan-2022': [(5, 1, 0.005, 0.01, 9, 0.9291458491039273),
#     (10, 1, 0.005, 0.005, 12, 0.7763135413384411),
#     (12, 1, 0.005, 0.005, 15, 1.0624771617542612),
#     (16, -1, 0.01, 0.005, 19, 0.4736411316599528),
#     (19, 1, 0.02, 0.01, 24, 3.215577670645768),
#     (24, 1, 0.01, 0.01, 27, 1.0959837685168707),
#     (33, -1, 0.005, 0.01, 41, 1.0966926734954905),
#     (45, -1, 0.005, 0.005, 48, 0.672164139193534),
#     (48, -1, 0.005, 0.005, 52, 0.5339965698329517),
#     (52, -1, 0.005, 0.005, 54, 0.6825805681974076),
#     (54, -1, 0.005, 0.005, 57, 0.897433373936553),
#     (57, -1, 0.02, 0.005, 60, 1.253661131943672),
#     (60, -1, 0.02, 0.005, 62, 1.5575146738145278),
#     (62, -1, 0.01, 0.005, 66, 0.854734428226992),
#     (66, -1, 0.005, 0.005, 68, 0.7060805713176315),
#     (70, -1, 0.005, 0.005, 71, 0.0471066937983861)],
#    '31-Jan-2022': [(5, -1, 0.005, 0.005, 9, 1.2430915439450005),
#     (9, -1, 0.02, 0.005, 19, 0.6944444444444451),
#     (22, -1, 0.005, 0.01, 25, 1.0034657696100688),
#     (25, -1, 0.005, 0.01, 34, 1.0935611793127225),
#     (36, -1, 0.01, 0.005, 43, 0.4578797402093926),
#     (46, 1, 0.02, 0.01, 48, 0.06009370705790934)]},
#   'KOTAKBANK.NS': {'21-Jan-2022': [(9, 1, 0.005, 0.02, 69, 2.0664735991379413),
#     (71, -1, 0.02, 0.01, 72, 0.2292763157894814)],
#    '01-Feb-2022': [(13, -1, 0.005, 0.01, 27, 1.1143736251027936),
#     (28, 1, 0.01, 0.01, 34, 0.9809088441245208),
#     (41, -1, 0.005, 0.01, 48, 1.8705853690959713),
#     (49, 1, 0.005, 0.005, 52, 0.5494038461665155),
#     (52, 1, 0.005, 0.005, 55, 0.5882265220288974),
#     (58, 1, 0.02, 0.005, 66, 0.7501003152073072),
#     (67, 1, 0.005, 0.005, 74, 0.7167859574111146)],
#    '14-Jan-2022': [(5, -1, 0.01, 0.01, 29, 0.934967618001442),
#     (32, 1, 0.01, 0.02, 70, 2.1958577908316577),
#     (73, 1, 0.02, 0.005, 74, 0.10141665424485428)]},
#   'SCHNEIDER.NS': {'11-Jan-2022': [(5,
#      1,
#      0.005,
#      0.005,
#      8,
#      0.46099483745402275),
#     (9, 1, 0.02, 0.005, 12, 2.483620689655175),
#     (12, 1, 0.005, 0.02, 14, 2.43983050847459),
#     (22, -1, 0.01, 0.01, 31, 1.3447422680412306),
#     (44, -1, 0.005, 0.005, 50, 0.4415326834304255),
#     (51, -1, 0.005, 0.005, 56, 0.5214817723790444),
#     (60, -1, 0.005, 0.005, 65, 0.9427083333333318),
#     (66, -1, 0.005, 0.005, 74, 0.5308823529411797)],
#    '10-Jan-2022': [(5, 1, 0.02, 0.005, 16, 1.686320989948219),
#     (18, -1, 0.005, 0.005, 24, 0.6499766377106172),
#     (31, 1, 0.005, 0.01, 47, 2.7656221646497414),
#     (47, -1, 0.005, 0.005, 50, 0.6219758028100777),
#     (51, 1, 0.005, 0.01, 56, 0.9682206875109178),
#     (57, -1, 0.005, 0.005, 60, 0.4963378256940046),
#     (60, 1, 0.005, 0.01, 68, 1.0581418057155634),
#     (68, -1, 0.005, 0.01, 73, 0.6596134392880022)],
#    '17-Jan-2022': [(24, 1, 0.02, 0.005, 28, 0.7163844742313678),
#     (29, -1, 0.005, 0.005, 39, 0.7562874139726992),
#     (42, -1, 0.005, 0.005, 48, 0.45873242372867906),
#     (51, -1, 0.005, 0.005, 64, 0.41553516960962605)],
#    '14-Jan-2022': [(10, -1, 0.005, 0.005, 16, 0.5847331668935792),
#     (25, 1, 0.005, 0.01, 29, 0.937470289600068),
#     (30, -1, 0.005, 0.005, 38, 0.8006387705835292),
#     (38, -1, 0.005, 0.005, 65, 0.5058837639163682)],
#    '12-Jan-2022': [(5, -1, 0.005, 0.005, 10, 0.7376569037656877),
#     (10, -1, 0.02, 0.005, 13, 0.9102645641706661),
#     (13, -1, 0.005, 0.01, 20, 1.0876284130549054),
#     (24, -1, 0.005, 0.01, 36, 0.9559071729957856),
#     (39, 1, 0.005, 0.005, 42, 0.4123063894418599),
#     (54, 1, 0.02, 0.005, 63, 0.5425814835377498),
#     (68, 1, 0.005, 0.02, 69, 0.3720321475414919)]}},
#  {'MUTHOOTFIN.NS 17-Jan-2022': 1.0868756122982919,
#   'WONDERLA.NS 01-Feb-2022': 2.938742571518116,
#   'VIPIND.NS 01-Feb-2022': 4.962142979744194,
#   'VIPIND.NS 24-Jan-2022': 8.42900943414488,
#   'VIPIND.NS 02-Feb-2022': 12.077812942357186,
#   'VIPIND.NS 14-Jan-2022': 3.4211885250148586,
#   'VIPIND.NS 13-Jan-2022': 1.9302510232776997,
#   'VIPIND.NS 19-Jan-2022': 7.948582682880438,
#   'VIPIND.NS 12-Jan-2022': 7.291327473775571,
#   'MTNL.NS 25-Jan-2022': 4.617700629761621,
#   'MTNL.NS 11-Jan-2022': 7.54770643059191,
#   'MTNL.NS 10-Jan-2022': 5.167206232002948,
#   'MTNL.NS 20-Jan-2022': 4.751023064762033,
#   'MTNL.NS 13-Jan-2022': 9.523652385071877,
#   'MTNL.NS 19-Jan-2022': 4.442190003719259,
#   'MTNL.NS 07-Jan-2022': 14.33857964146396,
#   'MTNL.NS 18-Jan-2022': 3.0848707086511853,
#   'MTNL.NS 31-Jan-2022': 6.918504204734746,
#   'TRF.NS 21-Jan-2022': 4.526903819518674,
#   'TRF.NS 11-Jan-2022': 0,
#   'TRF.NS 24-Jan-2022': 0,
#   'TRF.NS 02-Feb-2022': 0.6641221374045789,
#   'TRF.NS 19-Jan-2022': 0,
#   'TRF.NS 12-Jan-2022': 0,
#   'TRF.NS 07-Jan-2022': 1.8500046223134565,
#   'TRF.NS 31-Jan-2022': 0,
#   'TATAMTRDVR.NS 25-Jan-2022': 2.851834373980674,
#   'TATAMTRDVR.NS 20-Jan-2022': 2.8679252665904804,
#   'TATAMTRDVR.NS 18-Jan-2022': 3.2310297415289377,
#   'VARDHACRLC.NS 25-Jan-2022': 7.583366909934784,
#   'VARDHACRLC.NS 21-Jan-2022': 5.950723625808132,
#   'VARDHACRLC.NS 10-Jan-2022': 4.817415255842028,
#   'VARDHACRLC.NS 24-Jan-2022': 4.169494034448654,
#   'VARDHACRLC.NS 17-Jan-2022': 13.122925654857392,
#   'VARDHACRLC.NS 20-Jan-2022': 10.975758017585939,
#   'VARDHACRLC.NS 02-Feb-2022': 3.2587351824914816,
#   'VARDHACRLC.NS 13-Jan-2022': 3.8905161824282875,
#   'VARDHACRLC.NS 07-Jan-2022': 9.405490575473067,
#   'VARDHACRLC.NS 18-Jan-2022': 15.855103946776364,
#   'VARDHACRLC.NS 31-Jan-2022': 4.552536384579539,
#   'KOTAKBANK.NS 21-Jan-2022': 2.2957499149274225,
#   'KOTAKBANK.NS 01-Feb-2022': 6.57038447913712,
#   'KOTAKBANK.NS 14-Jan-2022': 3.232242063077954,
#   'SCHNEIDER.NS 11-Jan-2022': 9.165793445709001,
#   'SCHNEIDER.NS 10-Jan-2022': 8.906209353327142,
#   'SCHNEIDER.NS 17-Jan-2022': 2.346939481542372,
#   'SCHNEIDER.NS 14-Jan-2022': 2.8287259909935445,
#   'SCHNEIDER.NS 12-Jan-2022': 5.018377074508146})

# %% [markdown]
# Compute optimal strategies starting from position t for t in [0,t_max] with steps of step

# %%
t_max,step=75,5

# %%
optDT,optRT={},{}
for t in range(0,t_max+1,step):
    optDT[t],optRT[t]=compute_optimal(posD,min_row=t)
# Out:
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 0
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 0
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 0
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 0
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 0
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 0
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 5
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 5
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 5
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 5
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 5
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 5
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 10
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 10
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 10
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 10
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 10
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 10
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 15
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 15
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 15
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 15
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 15
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 15
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 20
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 20
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 20
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 20
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 20
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 20
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 25
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 25
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 25
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 25
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 25
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 25
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 30
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 30
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 30
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 30
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 30
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 30
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 35
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 35
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 35
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 35
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 35
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 35
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 40
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 40
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 40
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 40
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 40
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 40
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 45
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 45
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 45
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 45
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 45
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 45
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 50
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 50
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 50
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 50
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 50
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 50
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 55
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 55
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 55
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 55
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 55
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 55
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 60
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 60
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 60
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 60
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 60
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 60
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 65
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 65
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 65
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 65
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 65
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 65
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 70
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 70
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 70
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 70
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 70
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 70
# Computing optimal strategy for ICICIPRULI.NS on 17-Mar-2023 starting from 75
# Computing optimal strategy for ADANITRANS.NS on 17-Mar-2023 starting from 75
# Computing optimal strategy for HBSL.NS on 20-Mar-2023 starting from 75
# Computing optimal strategy for IMPEXFERRO.NS on 20-Mar-2023 starting from 75
# Computing optimal strategy for IMPEXFERRO.NS on 17-Mar-2023 starting from 75
# Computing optimal strategy for ZENITHSTL.NS on 20-Mar-2023 starting from 75

# %% [markdown]
# ## Trading Plots of Optimal Strategy

# %%
import plotly.graph_objects as go

# %%
import plotly.express as px

# %%
def annotate_action(rew,act,df):
    if rew[1]>=0:color='Green'
    else: color='Red'
    if act[0]==1:text='Buy'
    elif act[0]==-1:text='Sell'
    ann=dict(font=dict(color=color,size=15),x=df.index[rew[0]],y=df.iloc[rew[0]]['Close'],
             showarrow=True,text=text)
    return ann

# %%
def annotate_exit(rew,act,anns,df):
    if rew[1]>=0:color='Green'
    else: color='Red'
    X=[a['x'] for a in anns if a is not None]
    if df.index[rew[2]] in X: 
        idx=X.index(df.index[rew[2]])
        anns[idx]['text']='Ex&'+anns[idx]['text']
    else:
        anns+=[dict(font=dict(color=color,size=15),x=df.index[rew[2]],y=df.iloc[rew[2]]['Close'],
                    showarrow=True,text='Exit')]

# %%
def plot_ticker_date(optD,ticker,date):
    global fig
    df=feed.ndata[ticker][date]
    df=df.loc[df['Date']==date]
    fig = go.Figure(data=
        [go.Candlestick(x = df.index,
                        open  = df["Open"],
                        high  = df["High"],
                        low   = df["Low"],
                        close = df["Close"])]
    )
    # reward=np.round(bt.results[ticker][date]["tot"],2)
    reward=(lambda x: sum(x) if len(x)>0 else 0)([o[5] for o in optD[ticker][date]])
    fig.update_layout(
        title=f'{ticker} on {date} return {reward}',
        yaxis_title="Price"
    )
    anns=[]
    for s,a,_,_,e,r in optD[ticker][date]:
        anns+=[annotate_action((s,r,e),(a,s),df)]
    for s,a,_,_,e,r in optD[ticker][date]:
        anns+=[annotate_exit((s,r,e),(a,s),anns,df)]
    
    # for r,a in zip(bt.results[ticker][date]['rew'],bt.results[ticker][date]['acts']):
    #     anns+=[annotate_action(r,a,df)]
    # for r,a in zip(bt.results[ticker][date]['rew'],bt.results[ticker][date]['acts']):
    #     anns+=[annotate_exit(r,a,anns,df)]
    for a in anns: 
        if a is not None: fig.add_annotation(a)
    fig.show()
    return fig

# %%
def combine_plotly_figs_to_html(plotly_figs, html_fname, include_plotlyjs='cdn', 
                                separator=None, auto_open=False):
    with open(html_fname, 'w') as f:
        f.write(plotly_figs[0].to_html(include_plotlyjs=include_plotlyjs))
        for fig in plotly_figs[1:]:
            if separator:
                f.write(separator)
            f.write(fig.to_html(full_html=False, include_plotlyjs=False))

    if auto_open:
        import pathlib, webbrowser
        uri = pathlib.Path(html_fname).absolute().as_uri()
        webbrowser.open(uri)

# %%
figs=[]
for t in optD:
    for d in optD[t]:
        figs+=[plot_ticker_date(optD,t,d)]

# %%
# # upload kaggle.json
# from google.colab import files
# uploaded=files.upload()

# %%
# !mkdir /root/.kaggle
# !mv ./kaggle.json /root/.kaggle/.
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# %mkdir data
# %cd data
# !kaggle datasets download -d gmshroff/marketdatafivemin
# !unzip marketdatafivemin.zip
# %cd ..

# %%
# DATAFILE='augdata_16-Dec-2022_5m.csv'
# if not colab: DATAPATH='~/DataLocal/algo_fin_new/five_min_data/'
# else: DATAPATH='./data/'
# df=pd.read_csv(DATAPATH+DATAFILE)

# %%
# dataFeed=DataFeed(tickers=list(df.ticker.unique()[0:50]),dfgiven=True,df=df)

# %%
# bt=Backtest(dataFeed,tickers=dataFeed.tickers,target=.05,stop=.01,txcost=0.001,
#             loc_exit=True,scan=True,topk=3,deploy=True)

# %%
# bt.run_all(tickers=dataFeed.tickers,model=momStrat)

# %%
# bt.results

# %%
# bt.returns

# %% [markdown]
# Experiments

# %% [markdown]
# # Computing Optimal Labels
# Backtesting a Always Buy/Sell Strategies to compute Optimal strategy for a day-ticker combination using MILP

# %%
# !pip install import_ipynb --quiet
# !pip install anvil-uplink --quiet
# !pip install yfinance --quiet
# !pip install pandas_ta --quiet
# !pip install ipynb --quiet
# !pip install rpyc --quiet
# !pip install pulp

# %%
# # pull files from Github
# !git clone https://github.com/gmshroff/algostrats.git

# %%
# %cd algostrats

# %%
# change to True if on colab
colab=False

# %%
import pandas as pd
import numpy as np
import import_ipynb
from backtest import Backtest
from feeds import BackFeed,DataFeed
from validation import Validate
import pickle
from itertools import product
from tqdm.notebook import tqdm
# Out:
# importing Jupyter notebook from backtest.ipynb
# importing Jupyter notebook from feeds.ipynb
# importing Jupyter notebook from synfeed.ipynb
# importing Jupyter notebook from india_calendar.ipynb
# importing Jupyter notebook from featfuncs.ipynb
# importing Jupyter notebook from feed_env.ipynb
# importing Jupyter notebook from validation.ipynb

# %%
from rulestrats import RuleStrat,do_nothing,always_buy,always_sell
# Out:
# importing Jupyter notebook from rulestrats.ipynb

# %%
from pulp_jobs import Jobs
from featfuncs import feat_aug,add_addl_features_feed,add_ta_features_feed,add_sym_feature_feed
from featfuncs import add_global_indices_feed
# Out:
# importing Jupyter notebook from pulp_jobs.ipynb

# %%
import warnings
warnings.simplefilter("ignore")

# %%
loadfeed=True
savefeed=False
synthetic=False

# %% [markdown]
# Deterministic Strategy - 1 or -1

# %%
class DetStrat(RuleStrat):
    def __init__(self,action=0):
        self.action=action
        self.data_cols=['row_num','Close']
        self.model_type='rule-based'
        super().__init__()
    def check_entry_batch(self,dfD):
        if self.action==-1: return always_sell(dfD)
        elif self.action==1: return always_buy(dfD)
        else: return do_nothing(dfD)

# %%
data=pd.read_csv('./capvol100.csv')

# %%
tickers=list(data.iloc[0:50]['ticker'].values)

# %%
def stringify(x):
    return pd.to_datetime(x['Datetime']).strftime('%d-%b-%Y')

# %%
loadfeed_path = '../algodata/btfeed_hp_11_test.pkl'

# %%
if not loadfeed:
    feed=BackFeed(tickers=tickers,nd=3,nw=1,synthetic=synthetic)
    if savefeed: 
        with open('../../temp_data/feed.pickle','wb') as f: pickle.dump(feed,f)
elif loadfeed:
    with open(loadfeed_path,'rb') as f: feed=pickle.load(f)

# %% [markdown]
# Gather Data for Computing Optimal Strategies for a given Feed

# %%
def assemble_backtests(feed,topk=3,actions=[-1,1],
                       stops=[.01,.005,.02],
                       targets=[.01,.005,.02]):
    posD={}
    print('Assembling backtests')
    for idx, (action,stop,target) in tqdm(enumerate([c for c in product(actions,stops,targets)])):
        detStrat=DetStrat(action)
        try:
            with open(loadfeed_path,'rb') as f: feed=pickle.load(f)
            bt=Backtest(feed,tickers=feed.tickers,add_features=True,target=target,stop=stop,txcost=0.001,
                        loc_exit=True,scan=True,topk=3,deploy=False,save_dfs=False)
        except:
            print(f'Error on idx: {idx, action, stop, target}, datesQ: {feed.datesQ}')
            continue
        bt.run_all(tickers=feed.tickers,model=detStrat,verbose=False)
        for t in bt.results:
            if t not in posD: posD[t]={}
            for d in bt.results[t]:
                if d not in posD[t]: posD[t][d]=[]
                max_r=0
                max_e=0
                for p in bt.results[t][d]['rew']:
                    if p[1]>0 and (p[1]>max_r or p[0]>=max_e): 
                        posD[t][d]+=[(p[0],p[2],p[1],(p[0],action,stop,target,p[2],p[1]))]
                        max_r,max_e=max(max_r,p[1]),max(max_e,p[2])
    return posD

# %%
def compute_optimal(posD,min_row=0):
    optD={}
    for t in posD:
        if t not in optD: optD[t]={}
        for d in posD[t]:
            # print(f'Computing optimal strategy for {t} on {d} starting from {min_row}')
            jobs=Jobs()
            for p in posD[t][d]:
                if p[0]>=min_row: jobs.add_job(p[0],p[1],p[2],p[3])
            if jobs.k>0:
                jobs.setup()
                jobs.solve()
                x=jobs.get_soln()
                optD[t][d]=[j for i,j in enumerate(jobs.dL) if x[i]>0]
            else: optD[t][d]=[]
    [optD[t][d].sort(key=lambda x: x[0]) for t in optD for d in optD[t]]
    optR={t+' '+d:(lambda x: sum(x) if len(x)>0 else 0)([o[5] for o in optD[t][d]]) for t in optD for d in optD[t]}
    return optD,optR

# %%
loadposD=False

# %%
if loadfeed:
    posD_path = loadfeed_path.rstrip('.pkl') + "_optimal_posD.pkl"
else:
    posD_path = 'posD.pkl'

# %%
if loadposD: 
    with open(posD_path,'rb') as f: posD=pickle.load(f)
else: 
    posD=assemble_backtests(feed)
    with open(posD_path,'wb') as f: pickle.dump(posD,f)
# Out:
# Assembling backtests
# 0it [00:00, ?it/s]

# %%
optD,optR=compute_optimal(posD,min_row=5)

# %%
optD,optR
# Out:
# ({'SYN': {'28-Oct-2022': [(6, -1, 0.01, 0.02, 9, 2.1315897935066546),
#     (9, -1, 0.02, 0.01, 12, 1.6945039221041598),
#     (12, -1, 0.01, 0.02, 18, 2.010422661392934),
#     (18, 1, 0.005, 0.02, 25, 2.1834505795318018),
#     (25, 1, 0.005, 0.02, 29, 2.8002418672683467),
#     (29, 1, 0.005, 0.02, 32, 2.299520904254923),
#     (32, 1, 0.02, 0.02, 35, 2.5032985824716545),
#     (35, 1, 0.02, 0.02, 38, 2.5251277661610563),
#     (38, 1, 0.02, 0.02, 41, 2.383097173867968),
#     (41, 1, 0.005, 0.02, 44, 2.1033189706197137),
#     (44, 1, 0.01, 0.02, 48, 2.520782103322164),
#     (48, 1, 0.01, 0.02, 53, 1.9092749951849857),
#     (53, -1, 0.005, 0.02, 64, 2.2083288135864665),
#     (64, -1, 0.02, 0.005, 66, 0.6946574108080288),
#     (66, -1, 0.02, 0.02, 70, 2.8775601848259504),
#     (70, -1, 0.005, 0.02, 73, 2.260165438302639),
#     (73, -1, 0.01, 0.01, 74, 1.1680213943303372)],
#    '20-Dec-2022': [(6, 1, 0.005, 0.005, 9, 0.5434442015381525),
#     (10, -1, 0.02, 0.005, 13, 0.8723386864601892),
#     (13, -1, 0.02, 0.02, 17, 3.0266104803532468),
#     (17, -1, 0.005, 0.02, 20, 2.516929967808286),
#     (20, -1, 0.005, 0.02, 23, 2.27486662058463),
#     (23, -1, 0.02, 0.02, 28, 2.009989731479391),
#     (31, 1, 0.01, 0.02, 35, 3.1152232788789673),
#     (35, 1, 0.01, 0.02, 38, 2.5292722545675312),
#     (38, 1, 0.005, 0.02, 41, 1.9765081759269347),
#     (41, 1, 0.01, 0.005, 43, 0.6573273813321607),
#     (44, -1, 0.005, 0.02, 53, 2.427761323319883),
#     (53, -1, 0.005, 0.02, 56, 2.052907218592641),
#     (56, -1, 0.01, 0.02, 59, 2.115961532838467),
#     (59, -1, 0.01, 0.02, 63, 2.241814499318317),
#     (63, 1, 0.005, 0.01, 70, 1.2743059974043278),
#     (70, 1, 0.01, 0.005, 72, 0.8715350099600168),
#     (72, 1, 0.02, 0.02, 74, 2.184260708505461)],
#    '25-Jan-2023': [(37, -1, 0.01, 0.005, 74, 0.4038350414117557)],
#    '22-Feb-2023': [(7, -1, 0.02, 0.005, 10, 0.6884333795081133),
#     (11, -1, 0.005, 0.02, 18, 1.9913050053870005),
#     (18, -1, 0.01, 0.02, 27, 1.9231897108758558),
#     (30, 1, 0.005, 0.02, 55, 2.184091083859826),
#     (55, 1, 0.02, 0.01, 60, 1.219828331960326),
#     (60, 1, 0.005, 0.005, 63, 0.6355845071788363),
#     (63, 1, 0.01, 0.02, 70, 2.3090318413942907),
#     (70, 1, 0.01, 0.02, 74, 1.5540726337664712)],
#    '22-Nov-2022': [],
#    '15-Feb-2023': [(6, -1, 0.005, 0.005, 8, 0.6201052370742313),
#     (8, 1, 0.02, 0.02, 14, 3.1859779649084046),
#     (14, 1, 0.01, 0.01, 16, 1.6034825316654335),
#     (16, 1, 0.01, 0.02, 19, 3.7643367604925273),
#     (19, 1, 0.005, 0.02, 22, 3.3823324548062033),
#     (22, 1, 0.01, 0.02, 25, 2.2342917550416805),
#     (26, -1, 0.005, 0.02, 33, 2.6231404868515362),
#     (33, -1, 0.005, 0.02, 36, 3.089276858470466),
#     (36, -1, 0.02, 0.02, 39, 4.025679796857147),
#     (39, -1, 0.01, 0.005, 41, 1.9746674963458477),
#     (41, -1, 0.01, 0.02, 44, 2.9448363779384112),
#     (45, 1, 0.005, 0.02, 51, 2.8145159434806355),
#     (51, 1, 0.01, 0.02, 54, 3.9446046217932302),
#     (54, 1, 0.02, 0.02, 56, 2.1497112824236733),
#     (56, 1, 0.02, 0.005, 58, 2.046070172456979),
#     (58, 1, 0.005, 0.02, 61, 3.352945729582888),
#     (61, 1, 0.005, 0.01, 63, 0.9549053212042783),
#     (64, -1, 0.005, 0.02, 70, 2.532166131715799),
#     (70, -1, 0.01, 0.02, 73, 3.3895131134223133),
#     (73, -1, 0.005, 0.02, 74, 2.0390429380090156)],
#    '05-Dec-2022': [(6, -1, 0.02, 0.005, 9, 0.40458045334089465),
#     (11, 1, 0.02, 0.02, 16, 2.4725595787986165),
#     (16, 1, 0.01, 0.02, 20, 2.6762452287123706),
#     (20, 1, 0.01, 0.02, 24, 2.1240307757500583),
#     (24, 1, 0.005, 0.005, 27, 0.5654418405287579),
#     (29, -1, 0.005, 0.02, 35, 2.640836150831458),
#     (35, -1, 0.005, 0.005, 37, 0.7897535880669252),
#     (37, -1, 0.02, 0.02, 40, 3.274023065075755),
#     (40, -1, 0.01, 0.02, 43, 2.6311771132437167),
#     (43, -1, 0.01, 0.005, 45, 0.6923405487672211),
#     (45, 1, 0.005, 0.02, 51, 2.102043456040285),
#     (51, 1, 0.02, 0.02, 54, 2.989302286009604),
#     (54, 1, 0.005, 0.02, 57, 3.4080784301563267),
#     (57, 1, 0.005, 0.02, 60, 2.942071224202117),
#     (60, 1, 0.01, 0.005, 62, 0.9653889957818146),
#     (63, -1, 0.005, 0.01, 70, 1.6688458726949094),
#     (70, -1, 0.005, 0.01, 72, 1.216260375776691),
#     (72, -1, 0.02, 0.02, 74, 3.1480357591316213)],
#    '04-Nov-2022': [(12, 1, 0.02, 0.01, 64, 0.9183837957278566),
#     (64, 1, 0.01, 0.01, 74, 0.09453596279883834)],
#    '02-Jan-2023': [(27, 1, 0.005, 0.005, 54, 0.40338353106106245),
#     (55, 1, 0.005, 0.01, 74, 0.2614167758621804)],
#    '23-Nov-2022': [],
#    '03-Jan-2023': [(6, -1, 0.02, 0.01, 12, 0.943146741083735),
#     (12, -1, 0.005, 0.005, 16, 0.46645777654658505),
#     (16, -1, 0.01, 0.01, 24, 0.9606132616270341),
#     (26, -1, 0.01, 0.005, 35, 0.4155341189089736),
#     (44, 1, 0.01, 0.01, 55, 1.0444125232648063),
#     (57, 1, 0.005, 0.02, 69, 2.114286510386713),
#     (69, 1, 0.02, 0.02, 74, 1.014292362295756)],
#    '21-Feb-2023': [],
#    '27-Dec-2022': [(6, 1, 0.01, 0.01, 8, 2.387706789719303),
#     (8, 1, 0.01, 0.02, 11, 2.500095767845118),
#     (14, -1, 0.005, 0.02, 17, 2.991555892895929),
#     (17, -1, 0.01, 0.01, 19, 2.6025965251477494),
#     (19, -1, 0.01, 0.005, 21, 3.4763682850160276),
#     (21, -1, 0.005, 0.02, 23, 4.285625488665286),
#     (23, -1, 0.005, 0.02, 25, 4.9865943649732065),
#     (25, -1, 0.01, 0.02, 27, 5.509332320658863),
#     (27, -1, 0.01, 0.02, 29, 5.749377296414187),
#     (29, -1, 0.01, 0.01, 31, 5.566610011600944),
#     (31, -1, 0.01, 0.02, 33, 4.807267819181191),
#     (33, -1, 0.02, 0.01, 35, 3.3702637093247065),
#     (35, -1, 0.005, 0.005, 37, 1.315318402040548),
#     (39, 1, 0.01, 0.005, 41, 3.095595149405108),
#     (41, 1, 0.01, 0.005, 43, 4.794483797475565),
#     (43, 1, 0.01, 0.005, 45, 5.7813407884771975),
#     (45, 1, 0.01, 0.005, 47, 6.10253117819035),
#     (47, 1, 0.01, 0.01, 49, 5.914111469580498),
#     (49, 1, 0.01, 0.01, 51, 7.121816050968476),
#     (51, 1, 0.01, 0.01, 53, 6.2980634235005075),
#     (53, 1, 0.01, 0.01, 55, 4.987043078348614),
#     (55, 1, 0.01, 0.005, 57, 3.697587503666426),
#     (57, 1, 0.01, 0.005, 59, 2.4416994850573674),
#     (59, 1, 0.01, 0.005, 61, 1.2179513021798878),
#     (61, -1, 0.005, 0.01, 65, 1.3200014246393703),
#     (65, -1, 0.02, 0.005, 67, 2.14753277196703),
#     (67, -1, 0.01, 0.005, 69, 3.329096623717227),
#     (69, -1, 0.005, 0.01, 71, 4.51351777828352),
#     (71, -1, 0.01, 0.005, 73, 5.692036281250025),
#     (73, -1, 0.02, 0.005, 74, 6.8356698046666535)],
#    '14-Feb-2023': [(6, 1, 0.01, 0.01, 9, 1.531914353002398),
#     (9, 1, 0.01, 0.01, 12, 1.1405537232079366),
#     (12, 1, 0.01, 0.01, 16, 0.9764145152018326),
#     (17, -1, 0.005, 0.01, 25, 1.3278208335489239),
#     (25, -1, 0.02, 0.02, 30, 2.6246458079441215),
#     (30, -1, 0.005, 0.005, 32, 0.7954791806627683),
#     (32, -1, 0.02, 0.02, 36, 2.93252046888368),
#     (36, -1, 0.02, 0.02, 39, 2.0881168888622583),
#     (39, -1, 0.005, 0.02, 42, 2.0768280237929027),
#     (42, -1, 0.005, 0.02, 45, 1.919792152028985),
#     (45, -1, 0.01, 0.02, 49, 2.3588433910795517),
#     (49, -1, 0.005, 0.01, 52, 0.9962171820159472),
#     (53, 1, 0.005, 0.02, 64, 2.504136333509478),
#     (64, 1, 0.01, 0.005, 66, 0.7409792425930206),
#     (66, 1, 0.02, 0.02, 70, 2.9455216218918197),
#     (70, 1, 0.005, 0.02, 73, 2.1235627427091956),
#     (73, 1, 0.01, 0.01, 74, 1.0144449889119616)],
#    '11-Jan-2023': [(44, -1, 0.005, 0.005, 74, 0.25002493611795734)],
#    '15-Nov-2022': [(5, -1, 0.01, 0.005, 7, 3.6064568000199086),
#     (7, -1, 0.02, 0.005, 9, 1.3376328616203024),
#     (9, 1, 0.01, 0.005, 11, 1.1555964852323046),
#     (11, 1, 0.02, 0.01, 13, 3.587166026244934),
#     (13, 1, 0.005, 0.01, 15, 5.204898311497986),
#     (15, 1, 0.01, 0.02, 17, 5.845219291902858),
#     (17, 1, 0.01, 0.005, 19, 5.6598394958573595),
#     (19, 1, 0.005, 0.005, 21, 4.905732574247148),
#     (21, 1, 0.01, 0.01, 23, 3.809517882288654),
#     (23, 1, 0.01, 0.005, 25, 2.529465958338593),
#     (25, 1, 0.01, 0.01, 27, 1.1652159886764963),
#     (27, -1, 0.005, 0.01, 31, 2.303760760988554),
#     (31, -1, 0.005, 0.01, 33, 2.6876404154376186),
#     (33, -1, 0.005, 0.02, 35, 3.8631040445177365),
#     (35, -1, 0.005, 0.01, 37, 4.82359159529939),
#     (37, -1, 0.02, 0.005, 39, 3.051974365010234),
#     (39, -1, 0.01, 0.005, 41, 2.923822681731039),
#     (41, -1, 0.005, 0.01, 43, 2.3948610672043644),
#     (43, -1, 0.005, 0.01, 45, 1.4752553446346264),
#     (45, 1, 0.005, 0.01, 50, 2.240539740391882),
#     (50, 1, 0.01, 0.02, 52, 2.394651700781256),
#     (52, 1, 0.01, 0.01, 54, 2.984819948984963),
#     (54, 1, 0.005, 0.01, 56, 3.151512182336454),
#     (56, 1, 0.01, 0.01, 58, 2.9429632100648417),
#     (58, 1, 0.01, 0.01, 60, 2.4441957686848554),
#     (60, 1, 0.005, 0.02, 63, 3.2159506105690445),
#     (42, -1, 0.02, 0.01, 51, 0.9564621012117743),
#     (52, 1, 0.01, 0.02, 74, 2.047307288526303)],
#    '02-Feb-2023': [],
#    '21-Nov-2022': [(27, 1, 0.01, 0.005, 59, 0.41598415943499006),
#     (59, 1, 0.01, 0.005, 74, 0.14538162720551415)],
#    '28-Dec-2022': [(6, -1, 0.02, 0.005, 8, 8.381963570545693),
#     (8, -1, 0.01, 0.01, 10, 6.361630985463365),
#     (10, -1, 0.01, 0.02, 12, 2.6854501938239155),
#     (12, 1, 0.005, 0.02, 15, 6.108913617597058),
#     (15, 1, 0.02, 0.01, 17, 7.691554426092893),
#     (17, 1, 0.02, 0.01, 19, 9.51567699861888),
#     (19, 1, 0.02, 0.01, 21, 9.849642118451152),
#     (21, 1, 0.02, 0.01, 23, 9.260486840057602),
#     (23, 1, 0.01, 0.02, 25, 8.203644590664588),
#     (25, 1, 0.02, 0.01, 27, 2.182580661205429),
#     (27, 1, 0.01, 0.02, 29, 1.9260385365606192),
#     (29, 1, 0.005, 0.02, 32, 3.0714311818662225),
#     (33, 1, 0.01, 0.005, 35, 0.6898310994128386),
#     (35, -1, 0.005, 0.02, 43, 2.9344835529106525),
#     (43, -1, 0.01, 0.02, 46, 3.206475065198288),
#     (46, -1, 0.01, 0.02, 48, 1.9745395363943412),
#     (48, -1, 0.005, 0.02, 50, 2.188012316371886),
#     (50, -1, 0.01, 0.01, 52, 2.275058727022343),
#     (52, -1, 0.005, 0.01, 54, 2.2111929270428297),
#     (54, -1, 0.005, 0.01, 56, 1.9785124535531349),
#     (56, -1, 0.005, 0.02, 59, 2.958597722957271),
#     (59, -1, 0.005, 0.005, 61, 0.6834327516408133),
#     (61, 1, 0.005, 0.02, 67, 3.1004412750369688),
#     (67, 1, 0.02, 0.01, 69, 1.7418814881544376),
#     (69, 1, 0.02, 0.01, 71, 2.1101480397956354),
#     (71, 1, 0.02, 0.01, 73, 2.299029270586101),
#     (73, 1, 0.02, 0.01, 74, 2.3160787558610387)],
#    '07-Dec-2022': [(6, -1, 0.01, 0.01, 8, 3.77002769445451),
#     (8, -1, 0.02, 0.02, 10, 3.535623798474768),
#     (10, -1, 0.005, 0.02, 12, 3.1090380640664383),
#     (12, -1, 0.01, 0.02, 14, 2.4762740512831423),
#     (14, -1, 0.02, 0.02, 17, 2.897357977498602),
#     (18, 1, 0.005, 0.005, 21, 1.0186361793083556),
#     (21, 1, 0.005, 0.02, 24, 4.035656854986424),
#     (24, 1, 0.01, 0.01, 26, 2.9333727937016945),
#     (26, 1, 0.005, 0.01, 28, 3.4860491288349995),
#     (28, 1, 0.01, 0.005, 30, 3.8277834358229996),
#     (30, 1, 0.01, 0.005, 32, 3.9788780216673696),
#     (32, 1, 0.005, 0.02, 34, 3.9709019500155787),
#     (34, 1, 0.005, 0.02, 36, 3.8378422307041467),
#     (36, 1, 0.01, 0.02, 38, 3.610809190123697),
#     (38, 1, 0.01, 0.02, 40, 3.3157243033151595),
#     (40, 1, 0.005, 0.02, 42, 2.9729048017578674),
#     (42, 1, 0.01, 0.02, 44, 2.597609068538558),
#     (44, 1, 0.005, 0.02, 46, 2.200936088559595),
#     (46, 1, 0.01, 0.02, 49, 3.5049779725917927),
#     (49, 1, 0.01, 0.01, 51, 1.1616135170088462),
#     (51, 1, 0.01, 0.01, 54, 1.3687873984585281),
#     (54, -1, 0.005, 0.02, 62, 2.8915200363272353),
#     (62, -1, 0.01, 0.02, 65, 3.0278848761468655),
#     (65, -1, 0.02, 0.005, 67, 1.9778462147220948),
#     (67, -1, 0.01, 0.02, 69, 2.3640767204392867),
#     (69, -1, 0.005, 0.02, 71, 2.7307316909780566),
#     (71, -1, 0.02, 0.005, 73, 3.0692590676960196),
#     (73, -1, 0.005, 0.02, 74, 3.367828430907095)],
#    '20-Oct-2022': [(13, 1, 0.01, 0.005, 45, 0.41584765835857457),
#     (45, 1, 0.005, 0.005, 74, 0.3726255162033262)],
#    '19-Dec-2022': [(6, -1, 0.02, 0.005, 8, 1.0875927586050003),
#     (9, 1, 0.005, 0.005, 11, 0.44713504418634004),
#     (11, 1, 0.02, 0.02, 14, 3.6718180068040347),
#     (14, 1, 0.02, 0.01, 16, 2.6456620214397546),
#     (16, 1, 0.01, 0.01, 18, 2.9087908673609886),
#     (18, 1, 0.02, 0.01, 20, 2.8090478588396413),
#     (20, 1, 0.02, 0.005, 22, 2.414533044475527),
#     (22, 1, 0.01, 0.02, 25, 3.38266831747575),
#     (26, -1, 0.005, 0.02, 32, 2.280874608756612),
#     (32, -1, 0.005, 0.02, 35, 4.130758410088544),
#     (35, -1, 0.01, 0.02, 37, 2.6378939187455677),
#     (37, -1, 0.01, 0.02, 40, 2.4999771923548524),
#     (40, -1, 0.02, 0.02, 43, 1.979940061112136),
#     (43, -1, 0.005, 0.005, 45, 0.4978478336016521),
#     (45, 1, 0.005, 0.02, 52, 2.529204772343255),
#     (52, 1, 0.01, 0.02, 55, 2.4371895307760654),
#     (55, 1, 0.005, 0.02, 58, 2.551605207828318),
#     (58, 1, 0.005, 0.02, 61, 2.022499976106968),
#     (61, 1, 0.01, 0.005, 63, 0.560196164224253),
#     (63, -1, 0.005, 0.01, 70, 1.2931309743591548),
#     (70, -1, 0.005, 0.01, 72, 0.9302019679208486),
#     (72, -1, 0.02, 0.02, 74, 2.4265198805158223)],
#    '13-Oct-2022': [(6, 1, 0.01, 0.005, 10, 0.5125123628557231),
#     (12, -1, 0.005, 0.02, 23, 2.2432389097948824),
#     (23, -1, 0.005, 0.005, 26, 0.7311644116872127),
#     (26, -1, 0.01, 0.01, 30, 1.0519738913411154),
#     (30, -1, 0.01, 0.01, 36, 0.961094002036788),
#     (39, 1, 0.005, 0.02, 48, 2.2559549749468903),
#     (48, 1, 0.005, 0.02, 56, 2.086524962827587),
#     (57, -1, 0.005, 0.02, 74, 1.8891532344148703)],
#    '31-Oct-2022': [(6, -1, 0.02, 0.02, 12, 2.1823872882009265),
#     (12, -1, 0.005, 0.02, 18, 1.9327416393711616),
#     (18, -1, 0.005, 0.02, 26, 2.0588577552044502),
#     (29, -1, 0.005, 0.005, 34, 0.4070033659043399),
#     (40, 1, 0.005, 0.005, 46, 0.5464201410953563),
#     (46, 1, 0.01, 0.005, 50, 0.5996757900927963),
#     (50, 1, 0.02, 0.02, 58, 2.2863879548005412),
#     (58, 1, 0.01, 0.005, 61, 0.7269614650576358),
#     (61, 1, 0.01, 0.01, 65, 1.243693335221079),
#     (65, 1, 0.005, 0.01, 69, 1.318718015129562),
#     (69, 1, 0.005, 0.02, 74, 2.3280001567682307)],
#    '09-Jan-2023': [(6, -1, 0.02, 0.005, 12, 0.4320761422358449),
#     (15, 1, 0.005, 0.02, 26, 2.232555870303269),
#     (26, 1, 0.005, 0.02, 34, 1.953314531016356),
#     (40, -1, 0.005, 0.02, 49, 2.201879679724853),
#     (49, -1, 0.005, 0.02, 56, 2.0367705994464624),
#     (57, -1, 0.02, 0.005, 62, 0.4256785276134022),
#     (65, 1, 0.01, 0.01, 71, 1.2080273063063454),
#     (71, 1, 0.01, 0.005, 74, 0.6537526549035144)],
#    '13-Dec-2022': [(10, -1, 0.005, 0.02, 19, 2.287376132264594),
#     (19, -1, 0.005, 0.02, 27, 1.9058944976155965),
#     (29, 1, 0.005, 0.01, 35, 1.236212241802335),
#     (35, 1, 0.005, 0.01, 39, 1.2704864192069196),
#     (39, 1, 0.005, 0.005, 42, 0.7585382900404445),
#     (42, 1, 0.005, 0.005, 46, 0.5216082552431013),
#     (49, -1, 0.02, 0.02, 56, 2.308812656303627),
#     (57, -1, 0.005, 0.01, 61, 1.240544746733932),
#     (64, 1, 0.005, 0.02, 74, 2.3950392211496023)],
#    '06-Dec-2022': [(5, -1, 0.01, 0.01, 7, 1.6435333344709504),
#     (7, -1, 0.01, 0.02, 10, 2.9904494456442987),
#     (10, -1, 0.005, 0.02, 13, 2.3022534560302916),
#     (13, -1, 0.02, 0.02, 18, 2.103977111931313),
#     (18, 1, 0.005, 0.005, 22, 0.795480233842877),
#     (22, 1, 0.005, 0.01, 25, 1.7662260972494261),
#     (25, 1, 0.005, 0.005, 27, 1.2049026140919543),
#     (27, 1, 0.01, 0.02, 30, 3.1019071297283682),
#     (30, 1, 0.005, 0.02, 33, 3.531568046893011),
#     (33, 1, 0.01, 0.02, 36, 3.6750003018322865),
#     (36, 1, 0.005, 0.02, 39, 3.5632970858260196),
#     (39, 1, 0.01, 0.02, 42, 3.2420991751671884),
#     (42, 1, 0.01, 0.02, 45, 2.7598114669162856),
#     (45, 1, 0.01, 0.02, 48, 2.1608793898739482),
#     (48, 1, 0.005, 0.02, 52, 2.103739192764055),
#     (53, -1, 0.005, 0.02, 63, 2.149065540008938),
#     (63, -1, 0.02, 0.01, 66, 1.9265570411056305),
#     (66, -1, 0.005, 0.02, 69, 2.5252049539005923),
#     (69, -1, 0.005, 0.02, 72, 3.018354835217588),
#     (72, -1, 0.005, 0.02, 74, 3.369327615256042)],
#    '21-Dec-2022': [(6, 1, 0.01, 0.01, 9, 1.2630877190172278),
#     (10, -1, 0.02, 0.01, 13, 1.9491409122624328),
#     (13, -1, 0.005, 0.02, 16, 4.144401694702115),
#     (16, -1, 0.02, 0.02, 18, 2.708930792313894),
#     (18, -1, 0.005, 0.02, 20, 2.9554618075554346),
#     (20, -1, 0.01, 0.02, 22, 2.871372480673001),
#     (22, -1, 0.02, 0.02, 24, 2.403098677867162),
#     (24, -1, 0.01, 0.02, 27, 2.645083389343256),
#     (27, 1, 0.005, 0.005, 30, 0.7413820536639811),
#     (30, 1, 0.01, 0.02, 33, 4.114260614560088),
#     (33, 1, 0.005, 0.01, 35, 2.841096269877309),
#     (35, 1, 0.005, 0.02, 37, 3.0583766003458885),
#     (37, 1, 0.01, 0.01, 39, 2.8765271366751257),
#     (39, 1, 0.01, 0.01, 41, 2.4308954349793916),
#     (41, 1, 0.01, 0.02, 44, 3.3040447089708698),
#     (45, -1, 0.005, 0.02, 51, 2.8626989453798517),
#     (51, -1, 0.02, 0.02, 53, 2.0333439269578095),
#     (53, -1, 0.02, 0.01, 55, 2.5821952362659686),
#     (55, -1, 0.01, 0.02, 57, 2.8958765516182514),
#     (57, -1, 0.01, 0.02, 59, 2.8991187340647473),
#     (59, -1, 0.02, 0.02, 61, 2.531408972411273),
#     (61, -1, 0.01, 0.02, 64, 3.128139152396628),
#     (64, 1, 0.01, 0.02, 69, 2.739860789554033),
#     (69, 1, 0.01, 0.02, 71, 2.383039656479024),
#     (71, 1, 0.005, 0.02, 73, 2.904144065987522),
#     (73, 1, 0.005, 0.02, 74, 3.0230702735474173)],
#    '18-Jan-2023': [(6, 1, 0.005, 0.02, 10, 2.1937623285317844),
#     (12, -1, 0.005, 0.005, 16, 0.8938641907804679),
#     (16, -1, 0.02, 0.02, 20, 2.9017249334395396),
#     (20, -1, 0.02, 0.02, 23, 2.797316883174746),
#     (23, -1, 0.02, 0.02, 26, 3.723259584447573),
#     (26, -1, 0.005, 0.02, 28, 2.261483900584797),
#     (28, -1, 0.01, 0.02, 30, 2.1148057459371024),
#     (30, -1, 0.02, 0.02, 33, 3.434872436527914),
#     (33, -1, 0.005, 0.02, 37, 2.209908491419053),
#     (37, 1, 0.01, 0.02, 42, 3.172667577872418),
#     (42, 1, 0.005, 0.02, 45, 3.824327612483021),
#     (45, 1, 0.005, 0.02, 47, 2.225025967861839),
#     (47, 1, 0.005, 0.005, 49, 2.3260042857068535),
#     (49, 1, 0.02, 0.01, 51, 2.264711435870262),
#     (51, 1, 0.005, 0.005, 53, 2.0663284436896623),
#     (53, 1, 0.01, 0.02, 56, 3.464057571385297),
#     (56, 1, 0.01, 0.02, 59, 2.193242299041438),
#     (60, -1, 0.005, 0.02, 68, 2.932555417719716),
#     (68, -1, 0.02, 0.01, 70, 1.4725531324221344),
#     (70, -1, 0.005, 0.02, 73, 3.8603772512194148),
#     (73, -1, 0.01, 0.01, 74, 2.186338959991442)],
#    '30-Nov-2022': [(6, -1, 0.02, 0.02, 9, 3.1549286077244956),
#     (11, 1, 0.02, 0.02, 17, 3.318143551958104),
#     (17, 1, 0.02, 0.02, 20, 4.081812839037683),
#     (20, 1, 0.02, 0.01, 22, 2.36808621597167),
#     (22, 1, 0.005, 0.02, 24, 2.4680654036310945),
#     (24, 1, 0.005, 0.005, 26, 2.1757756823042382),
#   'SYN 16-Nov-2022': 64.0785749497827,
#   'SYN 09-Nov-2022': 0.7262214833250535,
#   'SYN 23-Feb-2023': 11.554381112102822,
#   'SYN 08-Feb-2023': 7.327802118523077,
#   'SYN 21-Oct-2022': 0.41468833366705116,
#   'SYN 16-Jan-2023': 5.527019849688589,
#   'SYN 02-Feb-2023': 0,
#   'SYN 21-Nov-2022': 0.5613657866405042,
#   'SYN 28-Dec-2022': 107.906728702886,
#   'SYN 07-Dec-2022': 83.03995155838975,
#   'SYN 20-Oct-2022': 0.7884731745619007,
#   'SYN 19-Dec-2022': 48.145088417921095,
#   'SYN 13-Oct-2022': 11.731616749905069,
#   'SYN 31-Oct-2022': 15.630846906846081,
#   'SYN 09-Jan-2023': 11.144055311550048,
#   'SYN 13-Dec-2022': 13.924512460360152,
#   'SYN 06-Dec-2022': 49.93363406775106,
#   'SYN 21-Dec-2022': 70.29005659746971,
#   'SYN 18-Jan-2023': 54.51918845010648,
#   'SYN 30-Nov-2022': 55.1319777752467})

# %% [markdown]
# Compute optimal strategies starting from position t for t in [0,t_max] with steps of step

# %%
t_max,step=70,5

# %%
optDT,optRT={},{}
for t in range(0,t_max+1,step):
    optDT[t],optRT[t]=compute_optimal(posD,min_row=t)
    print(f'Done for t={t}')
# Out:
# Done for t=0
# Done for t=5
# Done for t=10
# Done for t=15
# Done for t=20
# Done for t=25
# Done for t=30
# Done for t=35
# Done for t=40
# Done for t=45
# Done for t=50
# Done for t=55
# Done for t=60
# Done for t=65
# Done for t=70

# %%
feed = feed.data
for ticker in feed:
    feed[ticker]['row_num'] = feed[ticker]['row_num'].apply(lambda x: x if x<75 else x-75)

# %%
for ticker in feed:
    feed[ticker]['Action'] = -5
    actions = []

    for t in optD[ticker]:
        for acts in optD[ticker][t]:
            rn, a = acts[0], acts[1]
            actions.append(a)
            # if a == -1: a = 2
            feed[ticker].loc[(feed[ticker]['Date']==t) & (feed[ticker]['row_num']==rn), 'Action'] = a

# %%
feed_old = feed.copy()
feed = pd.concat([feed[t] for t in feed], axis=0)
feed
# Out:
#                                datetime         Date ticker      Open  \
# 2022-09-29 09:15:00 2022-09-29 09:15:00  29-Sep-2022    SYN  1.000000
# 2022-09-29 09:20:00 2022-09-29 09:20:00  29-Sep-2022    SYN  0.999894
# 2022-09-29 09:25:00 2022-09-29 09:25:00  29-Sep-2022    SYN  0.999788
# 2022-09-29 09:30:00 2022-09-29 09:30:00  29-Sep-2022    SYN  0.999682
# 2022-09-29 09:35:00 2022-09-29 09:35:00  29-Sep-2022    SYN  0.999577
# ...                                 ...          ...    ...       ...
# 2023-02-23 15:05:00 2023-02-23 15:05:00  23-Feb-2023    SYN  1.020304
# 2023-02-23 15:10:00 2023-02-23 15:10:00  23-Feb-2023    SYN  1.016286
# 2023-02-23 15:15:00 2023-02-23 15:15:00  23-Feb-2023    SYN  1.012240
# 2023-02-23 15:20:00 2023-02-23 15:20:00  23-Feb-2023    SYN  1.008172
# 2023-02-23 15:25:00 2023-02-23 15:25:00  23-Feb-2023    SYN  1.004089
#
# -5    5493
#  1     332
# -1     325
# Name: Action, dtype: int64

# %%
for ticker in feed_old:
    feed_old[ticker]['Action'] = -5
    actions = []

    for offset in optDT:
        for t in optDT[offset][ticker]:
            for acts in optDT[offset][ticker][t]:
                rn, a = acts[0], acts[1]
                actions.append(a)
                # if a == -1: a = 2
                feed_old[ticker].loc[(feed_old[ticker]['Date']==t) & (feed_old[ticker]['row_num']==rn), 'Action'] = a

# %%
feed_all = pd.concat([feed_old[t] for t in feed_old], axis=0)
feed_all['Action'].value_counts()
# Out:
# -5    5086
# -1     538
#  1     526
# Name: Action, dtype: int64

# %%
from dataclasses import dataclass

@dataclass
class OptimalData:
    optD: dict
    optR: dict
    optDT: dict
    optRT: dict
    feed_original: pd.DataFrame
    feed_all: pd.DataFrame

# %%
optimal_synthetic_hp_11 = OptimalData(optD=optD, optR=optR, feed_original=feed, optDT=optDT, optRT=optRT, feed_all=feed_all)

# %%
import os
with open(os.path.join('additional_utils', 'optimal_synthetic_hp11.pkl'), 'wb') as f:
    pickle.dump(optimal_synthetic_hp_11, f)

# %%
# from dataclasses import dataclass

# @dataclass
# class OptimalData:
#     optD: dict
#     optR: dict
#     optDT: dict
#     optRT: dict
#     feed_optimal: pd.DataFrame
#     feed_optimal_t: pd.DataFrame

# %%
import os
with open(os.path.join('additional_utils', 'optimal_alldata.pkl'), 'rb') as f:
    optimal_all_data = pickle.load(f)

# %%
optimal_all_data_2 = OptimalData(optimal_all_data.optD, optimal_all_data.optR, optimal_all_data.optDT, optimal_all_data.optRT, optimal_all_data.feed, None)

# %%
curr_feed = optimal_all_data_2.feed_optimal.copy()

for time in optimal_all_data_2.optDT:
    for ticker in optimal_all_data_2.optDT[time]:
        for t in optimal_all_data_2.optDT[time][ticker]:
            for acts in optimal_all_data_2.optDT[time][ticker][t]:
                rn, a = acts[0], acts[1]
                # actions.append(a)
                # if a == -1: a = 2
                try:
                    prev_action = curr_feed.loc[(curr_feed['Date']==t) & (curr_feed['row_num']==rn) & (curr_feed['ticker']==ticker), 'Action'].values[0]
                    curr_feed.loc[(curr_feed['Date']==t) & (curr_feed['row_num']==rn), 'Action'] = a
                    if prev_action!=-5 and prev_action != a:
                        print(f'Conflict: Prev:{prev_action} Curr:{a} where Date: {t} and row: {rn}')
                except:
                    print(f'Not found! {t},{ticker},{rn}')

# %%
optDT = optimal_all_data.optDT

# %%
data_store = {}

for offset in optDT:
    for ticker in optDT[offset]:
        for time in optDT[offset][ticker]:
            for acts in optDT[offset][ticker][time]:
                a, rn = acts[0], acts[1]

# %%
optimal_all_data = OptimalData(optD=optD, optR=optR, optDT=optDT, optRT=optRT, feed=feed)

import os
with open(os.path.join('additional_utils', 'optimal_alldata.pkl'), 'wb') as f:
    pickle.dump(optimal_all_data, f)

# %% [markdown]
# ## Trading Plots of Optimal Strategy

# %%
import plotly.graph_objects as go

# %%
import plotly.express as px

# %%
def annotate_action(rew,act,df):
    if rew[1]>=0:color='Green'
    else: color='Red'
    if act[0]==1:text='Buy'
    elif act[0]==-1:text='Sell'
    ann=dict(font=dict(color=color,size=15),x=df.index[rew[0]],y=df.iloc[rew[0]]['Close'],
             showarrow=True,text=text)
    return ann

# %%
def annotate_exit(rew,act,anns,df):
    if rew[1]>=0:color='Green'
    else: color='Red'
    X=[a['x'] for a in anns if a is not None]
    if df.index[rew[2]] in X: 
        idx=X.index(df.index[rew[2]])
        anns[idx]['text']='Ex&'+anns[idx]['text']
    else:
        anns+=[dict(font=dict(color=color,size=15),x=df.index[rew[2]],y=df.iloc[rew[2]]['Close'],
                    showarrow=True,text='Exit')]

# %%
def plot_ticker_date(optD,ticker,date):
    global fig
    df=feed.ndata[ticker][date]
    df=df.loc[df['Date']==date]
    fig = go.Figure(data=
        [go.Candlestick(x = df.index,
                        open  = df["Open"],
                        high  = df["High"],
                        low   = df["Low"],
                        close = df["Close"])]
    )
    # reward=np.round(bt.results[ticker][date]["tot"],2)
    reward=(lambda x: sum(x) if len(x)>0 else 0)([o[5] for o in optD[ticker][date]])
    fig.update_layout(
        title=f'{ticker} on {date} return {reward}',
        yaxis_title="Price"
    )
    anns=[]
    for s,a,_,_,e,r in optD[ticker][date]:
        anns+=[annotate_action((s,r,e),(a,s),df)]
    for s,a,_,_,e,r in optD[ticker][date]:
        anns+=[annotate_exit((s,r,e),(a,s),anns,df)]
    
    # for r,a in zip(bt.results[ticker][date]['rew'],bt.results[ticker][date]['acts']):
    #     anns+=[annotate_action(r,a,df)]
    # for r,a in zip(bt.results[ticker][date]['rew'],bt.results[ticker][date]['acts']):
    #     anns+=[annotate_exit(r,a,anns,df)]
    for a in anns: 
        if a is not None: fig.add_annotation(a)
    fig.show()
    return fig

# %%
def combine_plotly_figs_to_html(plotly_figs, html_fname, include_plotlyjs='cdn', 
                                separator=None, auto_open=False):
    with open(html_fname, 'w') as f:
        f.write(plotly_figs[0].to_html(include_plotlyjs=include_plotlyjs))
        for fig in plotly_figs[1:]:
            if separator:
                f.write(separator)
            f.write(fig.to_html(full_html=False, include_plotlyjs=False))

    if auto_open:
        import pathlib, webbrowser
        uri = pathlib.Path(html_fname).absolute().as_uri()
        webbrowser.open(uri)

# %%
figs=[]
for t in optD:
    for d in optD[t]:
        figs+=[plot_ticker_date(optD,t,d)]

# %%
# # upload kaggle.json
# from google.colab import files
# uploaded=files.upload()

# %%
# !mkdir /root/.kaggle
# !mv ./kaggle.json /root/.kaggle/.
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# %mkdir data
# %cd data
# !kaggle datasets download -d gmshroff/marketdatafivemin
# !unzip marketdatafivemin.zip
# %cd ..

# %%
# DATAFILE='augdata_16-Dec-2022_5m.csv'
# if not colab: DATAPATH='~/DataLocal/algo_fin_new/five_min_data/'
# else: DATAPATH='./data/'
# df=pd.read_csv(DATAPATH+DATAFILE)

# %%
# dataFeed=DataFeed(tickers=list(df.ticker.unique()[0:50]),dfgiven=True,df=df)

# %%
# bt=Backtest(dataFeed,tickers=dataFeed.tickers,target=.05,stop=.01,txcost=0.001,
#             loc_exit=True,scan=True,topk=3,deploy=True)

# %%
# bt.run_all(tickers=dataFeed.tickers,model=momStrat)

# %%
# bt.results

# %%
# bt.returns

# %% [markdown]
# Experiments
